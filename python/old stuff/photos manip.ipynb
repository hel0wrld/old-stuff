# %%
from skimage import io
import numpy as np
photo=io.imread("pepe.png")
# Out:
# (112, 112, 4)

# %%
import matplotlib.pyplot as plt
plt.imshow(photo)

# %%
masked=np.where(photo>100,255,0)
plt.imshow(masked)

# %%
plt.imshow(masked[::,0].T)

# %%
arr=np.array([2,3,6,0,2])
brr=np.array([5,7,0,2,4])
print(arr@brr) #dot product
print(arr+brr)
print(arr*brr)
print(arr*10)
print(arr+10)
print(np.sort(arr))
print(arr)
# Out:
# 39
# [ 7 10  6  2  6]
# [10 21  0  0  8]
# [20 30 60  0 20]
# [12 13 16 10 12]
# [0 2 2 3 6]
# [2 3 6 0 2]

# %%
plt.imshow(photo[80:112,70:112])
