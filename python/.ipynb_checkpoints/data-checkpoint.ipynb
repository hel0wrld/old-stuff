# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
# %matplotlib inline

ti_data = pd.read_csv("titanic.csv")
ti_data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
print(" Number of passengers =",len(ti_data.index))
# Out:
#  Number of passengers = 891

# %% [markdown]
# ## Analyze the data

# %%
sns.countplot(x='Survived', data=ti_data)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
ti_data["Sex"]
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: object

# %%
sns.set_theme()
sns.countplot(x="Sex", data=ti_data)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
sns.countplot(x='Survived', hue='Sex', data=ti_data)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
ti_data
# Out:
#      PassengerId  Fate  Pclass  \
# 0              1     0       3
# 1              2     1       1
# 2              3     1       3
# 3              4     1       1
# 4              5     0       3
# ..           ...   ...     ...
# 886          887     0       2
# 887          888     1       1
# 888          889     0       3
# 889          890     1       1
# 890          891     0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
ti_data['Fate'].replace({0:'Died',1:'Lived'}, inplace=True)
ti_data
# Out:
#      PassengerId   Fate  Pclass  \
# 0              1   Died       3
# 1              2  Lived       1
# 2              3  Lived       3
# 3              4  Lived       1
# 4              5   Died       3
# ..           ...    ...     ...
# 886          887   Died       2
# 887          888  Lived       1
# 888          889   Died       3
# 889          890  Lived       1
# 890          891   Died       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.countplot(x="Fate", hue='Sex', data=ti_data)
# Out:
# <AxesSubplot:xlabel='Fate', ylabel='count'>

# %%
ti_ages = ti_data['Age'].to_frame()
ti_ages.describe()
# Out:
#               Age
# count  714.000000
# mean    29.699118
# std     14.526497
# min      0.420000
# 25%     20.125000
# 50%     28.000000
# 75%     38.000000
# max     80.000000

# %%
index = ti_data.index[ti_data['Age']==0.42]
print(index)
# Out:
# Int64Index([803], dtype='int64')

# %%
print(ti_data.loc[803])
# Out:
# PassengerId                                804
# Fate                                     Lived
# Pclass                                       3
# Name           Thomas, Master. Assad Alexander
# Sex                                       male
# Age                                       0.42
# SibSp                                        0
# Parch                                        1
# Ticket                                    2625
# Fare                                    8.5167
# Cabin                                      NaN
# Embarked                                     C
# Name: 803, dtype: object

# %%
ti_data.rename(columns={'Fate':'Survived'}, inplace=True)
ti_data
# Out:
#      PassengerId Survived  Pclass  \
# 0              1     Died       3
# 1              2    Lived       1
# 2              3    Lived       3
# 3              4    Lived       1
# 4              5     Died       3
# ..           ...      ...     ...
# 886          887     Died       2
# 887          888    Lived       1
# 888          889     Died       3
# 889          890    Lived       1
# 890          891     Died       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
print(ti_data.loc[803])
# Out:
# PassengerId                                804
# Survived                                 Lived
# Pclass                                       3
# Name           Thomas, Master. Assad Alexander
# Sex                                       male
# Age                                       0.42
# SibSp                                        0
# Parch                                        1
# Ticket                                    2625
# Fare                                    8.5167
# Cabin                                      NaN
# Embarked                                     C
# Name: 803, dtype: object

# %%
ti_data['Survived'].replace({'Lived':1, 'Died':0}, inplace=True)

# %%
print(ti_data.loc[803])
# Out:
# PassengerId                                804
# Survived                                     1
# Pclass                                       3
# Name           Thomas, Master. Assad Alexander
# Sex                                       male
# Age                                       0.42
# SibSp                                        0
# Parch                                        1
# Ticket                                    2625
# Fare                                    8.5167
# Cabin                                      NaN
# Embarked                                     C
# Name: 803, dtype: object

# %% [markdown]
# ##
